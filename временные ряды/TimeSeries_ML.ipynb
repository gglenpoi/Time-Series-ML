# %% [markdown]
# # Машинное обучение для временных рядов

# %% [markdown]
# План семинара:
#
# 1. Обучение моделей
# 2. ETNA для построения прогнозов
# 3. Учет экзогенных факторов

# %%
# !pip install catboost -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.6/98.6 MB 10.8 MB/s eta 0:00:00

# %%
import warnings
warnings.filterwarnings('ignore')

from catboost import CatBoostRegressor

import matplotlib.dates as mdates
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.metrics import mean_squared_error, mean_absolute_error
from tqdm.notebook import tqdm

# %config InlineBackend.figure_format = 'svg'
from pylab import rcParams
rcParams['figure.figsize'] = 7, 5

# %% [markdown]
# ### Предобработка временного ряда  <a name="preprocess">

# %% [markdown]
# Возьмем датасет, в котором будет присутвовать переменная, изменяющася во времени. Давайте сегодня попробуем поработать с набором данных по среднесуточной дневной температуре в городе Дели, собранном за несколько лет. Подробнее почитать про датасет можно на [Kaggle](https://www.kaggle.com/sumanthvrao/daily-climate-time-series-data)
#
# Датасет сразу разбит на две части - train и test, но будем использовать для обучения и валидации моделей только train, оставив test как отложенную выборку для проверки качества.

# %%
df = pd.read_csv('https://raw.githubusercontent.com/aiedu-courses/stepik_applied_tasks/main/datasets/DailyDelhiClimateTrain.csv')

print(f"Дни с {min(df.date)} по {max(df.date)}, всего {df.date.nunique()} дней.")
df.head()
# Out:
# Дни с 2013-01-01 по 2016-12-31, всего 1461 дней.
#          date   meantemp   humidity  wind_speed  meanpressure
# 0  2013-01-01  10.000000  84.500000    0.000000   1015.666667
# 1  2013-01-02   7.400000  92.000000    2.980000   1017.800000
# 2  2013-01-03   7.166667  87.000000    4.633333   1018.666667
# 3  2013-01-04   8.666667  71.333333    1.233333   1017.166667
# 4  2013-01-05   6.000000  86.833333    3.700000   1016.500000

# %%
df['date'] = pd.to_datetime(df['date'], format = '%Y-%m-%d')

df = df[['date','meantemp']].set_index('date')

df.head()
# Out:
#              meantemp
# date
# 2013-01-01  10.000000
# 2013-01-02   7.400000
# 2013-01-03   7.166667
# 2013-01-04   8.666667
# 2013-01-05   6.000000

# %%
df.plot()
# Out:
# <Axes: xlabel='date'>

# %% [markdown]
# ### Генерация признаков <a name="features">

# %% [markdown]
# Основные подходы по генерации признаков:
#
# * лаговые признаки (lags) - значения ряда в предыдущие моменты времени
#
# * агрегации (среднее значение ряда по часу, дню, месяцу и так далее; медиана, дисперсия и так далее)

# %% [markdown]
# Напишем функцию, которая возвращает словарь, где ключами являются уникальные категории признака cat_feature, а значениями - средние по real_feature.

# %%
def code_mean(data, cat_feature, real_feature):
    return dict(data.groupby(cat_feature)[real_feature].mean())

# %%
df["month"] = df.index.month

d = code_mean(df, "month", "meantemp")

plt.plot(d.keys(), d.values())

# %% [markdown]
# Можно это удобно обернуть в функцию и заменить исходные признаки на их среднее как один из вариантов препроцессинга, а также - добавить значения целевой переменной с разной длинной временного лага.
#
# В функции мы:
#
# 1) Разбиваем данные на тренировочную и тестовую части
#
# 2) Генерируем лаговые признаки
#
# 3) Генерируем агрегированные признаки

# %%
def preprocess_data(data, lag_start=5, lag_end=20, test_size=0.15):

    data = pd.DataFrame(data.copy())

    # считаем индекс в датафрейме, после которого начинается тестовый отрезок
    test_index = int(len(data) * (1 - test_size))

    # добавляем лаги исходного ряда в качестве признаков
    for i in range(lag_start, lag_end):
        data[f"lag_{i}"] = data.meantemp.shift(i)

    data["weekday"] = data.index.weekday
    data["week"] = data.index.week
    data["month"] = data.index.month
    data["year"] = data.index.year

    # считаем средние только по тренировочной части, чтобы избежать лика (data leak)
    data["weekday_average"] = list(map(code_mean(data[:test_index], "weekday", "meantemp").get, data.weekday))
    data["week_average"] = list(map(code_mean(data[:test_index], "week", "meantemp").get, data.week))
    data["month_average"] = list(map(code_mean(data[:test_index], "month", "meantemp").get, data.month))
    data["year_average"] = list(map(code_mean(data[:test_index], "year", "meantemp").get, data.year))

    # выкидываем закодированные средними признаки
    data.drop(["weekday", "week", 'month', 'year'], axis=1, inplace=True)

    data = data.dropna()
    data = data.reset_index(drop=True)

    # разбиваем весь датасет на тренировочную и тестовую выборку
    X_train = data.loc[:test_index].drop(["meantemp"], axis=1)
    y_train = data.loc[:test_index]["meantemp"]
    X_test = data.loc[test_index:].drop(["meantemp"], axis=1)
    y_test = data.loc[test_index:]["meantemp"]

    return X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = preprocess_data(df, test_size=0.3, lag_start=3, lag_end=10)

X_train.head()
# Out:
#        lag_3      lag_4      lag_5     lag_6     lag_7     lag_8      lag_9  \
# 0   7.000000   7.000000   6.000000  8.666667  7.166667  7.400000  10.000000
# 1   8.857143   7.000000   7.000000  6.000000  8.666667  7.166667   7.400000
# 2  14.000000   8.857143   7.000000  7.000000  6.000000  8.666667   7.166667
# 3  11.000000  14.000000   8.857143  7.000000  7.000000  6.000000   8.666667
# 4  15.714286  11.000000  14.000000  8.857143  7.000000  7.000000   6.000000
#
#    weekday_average  week_average  month_average  year_average
# 0        25.440460     11.925454      12.738377     24.791494
# 1        25.372054     11.925454      12.738377     24.791494
# 2        25.331414     11.925454      12.738377     24.791494
# 3        25.202210     11.925454      12.738377     24.791494
# 4        25.499234     13.067177      12.738377     24.791494

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(X_train, y_train)

preds = lr.predict(X_test)

plt.figure(figsize=(10, 5))
plt.plot(preds, "r", label="prediction")
plt.plot(y_test.values, label="actual")
plt.grid(True)
plt.legend(loc="best")
plt.title(f"Linear regression\n Mean absolute error {mean_absolute_error(preds, y_test)} degrees");

# %%
coef_table = pd.DataFrame({'features' : list(X_train.columns), 'weights' : lr.coef_})

coef_table.sort_values(by='weights')
# Out:
#            features   weights
# 6             lag_9 -0.053074
# 4             lag_7 -0.018655
# 2             lag_5 -0.005313
# 3             lag_6  0.007803
# 5             lag_8  0.010311
# 9     month_average  0.025841
# 10     year_average  0.032261
# 1             lag_4  0.054898
# 0             lag_3  0.214654
# 8      week_average  0.757568
# 7   weekday_average  1.117083

# %% [markdown]
# ## DecisionTree

# %%
from sklearn.tree import DecisionTreeRegressor

dt = DecisionTreeRegressor()
dt.fit(X_train, y_train)
preds = dt.predict(X_test)

plt.figure(figsize=(10, 5))
plt.plot(preds, "r", label="prediction")
plt.plot(y_test.values, label="actual")
plt.grid(True)
plt.legend(loc="best")
plt.title(f"Linear regression\n Mean absolute error {mean_absolute_error(preds, y_test)} degrees");

# %% [markdown]
# ## RandomForest

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor()
rf.fit(X_train, y_train)
preds = rf.predict(X_test)

plt.figure(figsize=(10, 5))
plt.plot(preds, "r", label="prediction")
plt.plot(y_test.values, label="actual")
plt.grid(True)
plt.legend(loc="best")
plt.title(f"Linear regression\n Mean absolute error {mean_absolute_error(preds, y_test)} degrees");

# %% [markdown]
# ## CatBoost

# %%
cb = CatBoostRegressor(n_estimators=300)
cb.fit(X_train, y_train)
preds = cb.predict(X_test)

plt.figure(figsize=(10, 5))
plt.plot(preds, "r", label="prediction")
plt.plot(y_test.values, label="actual")
plt.grid(True)
plt.legend(loc="best")
plt.title(f"Linear regression\n Mean absolute error {mean_absolute_error(preds, y_test)} degrees");
# Out:
# Learning rate set to 0.109355
# 0:	learn: 6.5642868	total: 48.5ms	remaining: 14.5s
# 1:	learn: 5.9779800	total: 49.9ms	remaining: 7.43s
# 2:	learn: 5.4693442	total: 51.5ms	remaining: 5.1s
# 3:	learn: 5.0181396	total: 53ms	remaining: 3.92s
# 4:	learn: 4.6331338	total: 55.8ms	remaining: 3.29s
# 5:	learn: 4.2738236	total: 57.6ms	remaining: 2.82s
# 6:	learn: 3.9870835	total: 59.5ms	remaining: 2.49s
# 7:	learn: 3.7102953	total: 62.7ms	remaining: 2.29s
# 8:	learn: 3.4615438	total: 65.7ms	remaining: 2.12s
# 9:	learn: 3.2592037	total: 67.2ms	remaining: 1.95s
# 10:	learn: 3.0687529	total: 68.8ms	remaining: 1.81s
# 11:	learn: 2.8973073	total: 70.3ms	remaining: 1.69s
# 12:	learn: 2.7491643	total: 71.9ms	remaining: 1.59s
# 13:	learn: 2.6408101	total: 73.4ms	remaining: 1.5s
# 14:	learn: 2.5280247	total: 75ms	remaining: 1.43s
# 15:	learn: 2.4453114	total: 76.5ms	remaining: 1.36s
# 16:	learn: 2.3745100	total: 78.1ms	remaining: 1.3s
# 17:	learn: 2.3101646	total: 79.6ms	remaining: 1.25s
# 18:	learn: 2.2482794	total: 81.2ms	remaining: 1.2s
# 19:	learn: 2.2010836	total: 82.7ms	remaining: 1.16s
# 20:	learn: 2.1548721	total: 84.2ms	remaining: 1.12s
# 21:	learn: 2.1233938	total: 85.8ms	remaining: 1.08s
# 22:	learn: 2.0947806	total: 87.6ms	remaining: 1.05s
# 23:	learn: 2.0665401	total: 89.1ms	remaining: 1.02s
# 24:	learn: 2.0409570	total: 90.6ms	remaining: 997ms
# 25:	learn: 2.0198118	total: 92.1ms	remaining: 971ms
# 26:	learn: 2.0069714	total: 93.7ms	remaining: 948ms
# 27:	learn: 1.9919635	total: 95.3ms	remaining: 925ms
# 28:	learn: 1.9764534	total: 96.8ms	remaining: 905ms
# 29:	learn: 1.9620031	total: 98.3ms	remaining: 885ms
# 30:	learn: 1.9523241	total: 99.9ms	remaining: 867ms
# 31:	learn: 1.9427103	total: 102ms	remaining: 853ms
# 32:	learn: 1.9332243	total: 104ms	remaining: 838ms
# 33:	learn: 1.9233818	total: 105ms	remaining: 823ms
# 34:	learn: 1.9130348	total: 107ms	remaining: 808ms
# 35:	learn: 1.9024308	total: 108ms	remaining: 794ms
# 36:	learn: 1.8939935	total: 110ms	remaining: 781ms
# 37:	learn: 1.8877830	total: 111ms	remaining: 768ms
# 38:	learn: 1.8793092	total: 113ms	remaining: 756ms
# 39:	learn: 1.8718062	total: 115ms	remaining: 744ms
# 40:	learn: 1.8655424	total: 116ms	remaining: 733ms
# 41:	learn: 1.8580894	total: 118ms	remaining: 722ms
# 42:	learn: 1.8516711	total: 119ms	remaining: 711ms
# 43:	learn: 1.8445004	total: 120ms	remaining: 701ms
# 44:	learn: 1.8394459	total: 122ms	remaining: 691ms
# 45:	learn: 1.8321472	total: 123ms	remaining: 682ms
# 46:	learn: 1.8242632	total: 125ms	remaining: 673ms
# 47:	learn: 1.8208945	total: 127ms	remaining: 665ms
# 48:	learn: 1.8160909	total: 128ms	remaining: 657ms
# 49:	learn: 1.8098210	total: 130ms	remaining: 649ms
# 50:	learn: 1.8026470	total: 131ms	remaining: 641ms
# 51:	learn: 1.7950842	total: 133ms	remaining: 633ms
# 52:	learn: 1.7904418	total: 134ms	remaining: 625ms
# 53:	learn: 1.7870051	total: 136ms	remaining: 618ms
# 54:	learn: 1.7814519	total: 137ms	remaining: 611ms
# 55:	learn: 1.7754133	total: 139ms	remaining: 605ms
# 56:	learn: 1.7706350	total: 140ms	remaining: 598ms
# 57:	learn: 1.7649833	total: 142ms	remaining: 592ms
# 58:	learn: 1.7601723	total: 143ms	remaining: 586ms
# 59:	learn: 1.7544036	total: 146ms	remaining: 585ms
# 60:	learn: 1.7449001	total: 149ms	remaining: 582ms
# 61:	learn: 1.7378218	total: 152ms	remaining: 584ms
# 62:	learn: 1.7338608	total: 156ms	remaining: 587ms
# 63:	learn: 1.7307261	total: 158ms	remaining: 582ms
# 64:	learn: 1.7214866	total: 160ms	remaining: 578ms
# 65:	learn: 1.7129648	total: 161ms	remaining: 572ms
# 66:	learn: 1.7045571	total: 163ms	remaining: 566ms
# 67:	learn: 1.6998807	total: 164ms	remaining: 561ms
# 68:	learn: 1.6950560	total: 166ms	remaining: 556ms
# 69:	learn: 1.6894067	total: 168ms	remaining: 550ms
# 70:	learn: 1.6847320	total: 169ms	remaining: 545ms
# 71:	learn: 1.6797077	total: 171ms	remaining: 540ms
# 72:	learn: 1.6735914	total: 172ms	remaining: 535ms
# 73:	learn: 1.6660532	total: 174ms	remaining: 530ms
# 74:	learn: 1.6604078	total: 175ms	remaining: 525ms
# 75:	learn: 1.6568895	total: 177ms	remaining: 521ms
# 76:	learn: 1.6541922	total: 178ms	remaining: 516ms
# 77:	learn: 1.6508090	total: 180ms	remaining: 511ms
# 78:	learn: 1.6439562	total: 181ms	remaining: 507ms
# 79:	learn: 1.6375367	total: 186ms	remaining: 510ms
# 80:	learn: 1.6306915	total: 187ms	remaining: 506ms
# 81:	learn: 1.6251180	total: 189ms	remaining: 502ms
# 82:	learn: 1.6196700	total: 193ms	remaining: 504ms
# 83:	learn: 1.6162386	total: 195ms	remaining: 501ms
# 84:	learn: 1.6099475	total: 197ms	remaining: 498ms
# 85:	learn: 1.6052186	total: 198ms	remaining: 493ms
# 86:	learn: 1.6018252	total: 200ms	remaining: 489ms
# 87:	learn: 1.5959179	total: 201ms	remaining: 485ms
# 88:	learn: 1.5917505	total: 203ms	remaining: 480ms
# 89:	learn: 1.5880697	total: 204ms	remaining: 476ms
# 90:	learn: 1.5801421	total: 205ms	remaining: 472ms
# 91:	learn: 1.5734485	total: 207ms	remaining: 467ms
# 92:	learn: 1.5707749	total: 208ms	remaining: 463ms
# 93:	learn: 1.5691374	total: 210ms	remaining: 459ms
# 94:	learn: 1.5607152	total: 211ms	remaining: 456ms
# 95:	learn: 1.5521428	total: 213ms	remaining: 452ms
# 96:	learn: 1.5484359	total: 214ms	remaining: 448ms
# 97:	learn: 1.5468048	total: 216ms	remaining: 445ms
# 98:	learn: 1.5433905	total: 217ms	remaining: 441ms
# 99:	learn: 1.5367673	total: 219ms	remaining: 438ms
# 100:	learn: 1.5326545	total: 221ms	remaining: 435ms
# 101:	learn: 1.5294163	total: 222ms	remaining: 431ms
# 102:	learn: 1.5255587	total: 224ms	remaining: 428ms
# 103:	learn: 1.5184861	total: 225ms	remaining: 424ms
# 104:	learn: 1.5103325	total: 227ms	remaining: 422ms
# 105:	learn: 1.5079085	total: 229ms	remaining: 418ms
# 106:	learn: 1.5043281	total: 230ms	remaining: 415ms
# 107:	learn: 1.4975191	total: 232ms	remaining: 412ms
# 108:	learn: 1.4931566	total: 233ms	remaining: 409ms
# 109:	learn: 1.4884079	total: 235ms	remaining: 406ms
# 110:	learn: 1.4827935	total: 237ms	remaining: 403ms
# 111:	learn: 1.4760049	total: 238ms	remaining: 399ms
# 112:	learn: 1.4707505	total: 240ms	remaining: 396ms
# 113:	learn: 1.4634128	total: 241ms	remaining: 393ms
# 114:	learn: 1.4557903	total: 243ms	remaining: 390ms
# 115:	learn: 1.4530225	total: 244ms	remaining: 387ms
# 116:	learn: 1.4470964	total: 246ms	remaining: 384ms
# 117:	learn: 1.4460475	total: 247ms	remaining: 381ms
# 118:	learn: 1.4455222	total: 249ms	remaining: 379ms
# 119:	learn: 1.4423724	total: 251ms	remaining: 376ms
# 120:	learn: 1.4370688	total: 252ms	remaining: 373ms
# 121:	learn: 1.4338373	total: 254ms	remaining: 370ms
# 122:	learn: 1.4306385	total: 255ms	remaining: 367ms
# 123:	learn: 1.4257912	total: 257ms	remaining: 364ms
# 124:	learn: 1.4227439	total: 258ms	remaining: 362ms
# 125:	learn: 1.4168832	total: 260ms	remaining: 359ms
# 126:	learn: 1.4152000	total: 261ms	remaining: 356ms
# 127:	learn: 1.4101633	total: 263ms	remaining: 354ms
# 128:	learn: 1.4045186	total: 265ms	remaining: 351ms
# 129:	learn: 1.4006027	total: 266ms	remaining: 348ms
# 130:	learn: 1.3990812	total: 268ms	remaining: 345ms
# 131:	learn: 1.3918306	total: 269ms	remaining: 343ms
# 132:	learn: 1.3861969	total: 271ms	remaining: 340ms
# 133:	learn: 1.3845615	total: 273ms	remaining: 338ms
# 134:	learn: 1.3828278	total: 274ms	remaining: 335ms
# 135:	learn: 1.3770914	total: 276ms	remaining: 333ms
# 136:	learn: 1.3739213	total: 277ms	remaining: 330ms
# 137:	learn: 1.3684140	total: 279ms	remaining: 327ms
# 138:	learn: 1.3640646	total: 280ms	remaining: 325ms
# 139:	learn: 1.3579297	total: 282ms	remaining: 322ms
# 140:	learn: 1.3545541	total: 284ms	remaining: 320ms
# 141:	learn: 1.3505058	total: 285ms	remaining: 317ms
# 142:	learn: 1.3458239	total: 287ms	remaining: 315ms
# 143:	learn: 1.3421572	total: 288ms	remaining: 312ms
# 144:	learn: 1.3369122	total: 290ms	remaining: 310ms
# 145:	learn: 1.3340811	total: 291ms	remaining: 307ms
# 146:	learn: 1.3304523	total: 293ms	remaining: 305ms
# 147:	learn: 1.3259011	total: 295ms	remaining: 303ms
# 148:	learn: 1.3218072	total: 296ms	remaining: 300ms
# 149:	learn: 1.3166009	total: 298ms	remaining: 298ms
# 150:	learn: 1.3118322	total: 300ms	remaining: 296ms
# 151:	learn: 1.3079417	total: 301ms	remaining: 293ms
# 152:	learn: 1.3017835	total: 303ms	remaining: 291ms
# 153:	learn: 1.2995418	total: 304ms	remaining: 288ms
# 154:	learn: 1.2969388	total: 306ms	remaining: 287ms
# 155:	learn: 1.2923914	total: 308ms	remaining: 284ms
# 156:	learn: 1.2902869	total: 310ms	remaining: 282ms
# 157:	learn: 1.2853104	total: 311ms	remaining: 280ms
# 158:	learn: 1.2835575	total: 313ms	remaining: 278ms
# 159:	learn: 1.2816565	total: 315ms	remaining: 275ms
# 160:	learn: 1.2791632	total: 316ms	remaining: 273ms
# 161:	learn: 1.2768676	total: 318ms	remaining: 271ms
# 162:	learn: 1.2737123	total: 319ms	remaining: 268ms
# 163:	learn: 1.2706169	total: 321ms	remaining: 266ms
# 164:	learn: 1.2654883	total: 322ms	remaining: 264ms
# 165:	learn: 1.2600624	total: 324ms	remaining: 262ms
# 166:	learn: 1.2553481	total: 326ms	remaining: 259ms
# 167:	learn: 1.2538508	total: 327ms	remaining: 257ms
# 168:	learn: 1.2531072	total: 329ms	remaining: 255ms
# 169:	learn: 1.2479379	total: 330ms	remaining: 253ms
# 170:	learn: 1.2466148	total: 332ms	remaining: 250ms
# 171:	learn: 1.2441793	total: 334ms	remaining: 248ms
# 172:	learn: 1.2403470	total: 335ms	remaining: 246ms
# 173:	learn: 1.2382028	total: 337ms	remaining: 244ms
# 174:	learn: 1.2326920	total: 340ms	remaining: 243ms
# 175:	learn: 1.2308365	total: 341ms	remaining: 240ms
# 176:	learn: 1.2258356	total: 343ms	remaining: 238ms
# 177:	learn: 1.2232392	total: 344ms	remaining: 236ms
# 178:	learn: 1.2193331	total: 345ms	remaining: 233ms
# 179:	learn: 1.2147716	total: 347ms	remaining: 231ms
# 180:	learn: 1.2108444	total: 348ms	remaining: 229ms
# 181:	learn: 1.2086775	total: 349ms	remaining: 226ms
# 182:	learn: 1.2046892	total: 351ms	remaining: 224ms
# 183:	learn: 1.2027281	total: 352ms	remaining: 222ms
# 184:	learn: 1.2011428	total: 354ms	remaining: 220ms
# 185:	learn: 1.1977259	total: 356ms	remaining: 218ms
# 186:	learn: 1.1921576	total: 357ms	remaining: 216ms
# 187:	learn: 1.1909421	total: 359ms	remaining: 214ms
# 188:	learn: 1.1859724	total: 360ms	remaining: 212ms
# 189:	learn: 1.1814192	total: 362ms	remaining: 210ms
# 190:	learn: 1.1775841	total: 364ms	remaining: 208ms
# 191:	learn: 1.1742482	total: 365ms	remaining: 205ms
# 192:	learn: 1.1696383	total: 367ms	remaining: 203ms
# 193:	learn: 1.1677453	total: 368ms	remaining: 201ms
# 194:	learn: 1.1640068	total: 370ms	remaining: 199ms
# 195:	learn: 1.1622349	total: 371ms	remaining: 197ms
# 196:	learn: 1.1581193	total: 373ms	remaining: 195ms
# 197:	learn: 1.1563007	total: 375ms	remaining: 193ms
# 198:	learn: 1.1518925	total: 376ms	remaining: 191ms
# 199:	learn: 1.1456036	total: 379ms	remaining: 190ms
# 200:	learn: 1.1410364	total: 382ms	remaining: 188ms
# 201:	learn: 1.1364704	total: 385ms	remaining: 187ms
# 202:	learn: 1.1341071	total: 386ms	remaining: 185ms
# 203:	learn: 1.1326836	total: 388ms	remaining: 182ms
# 204:	learn: 1.1306003	total: 389ms	remaining: 180ms
# 205:	learn: 1.1264394	total: 390ms	remaining: 178ms
# 206:	learn: 1.1241362	total: 391ms	remaining: 176ms
# 207:	learn: 1.1221510	total: 394ms	remaining: 174ms
# 208:	learn: 1.1177351	total: 397ms	remaining: 173ms
# 209:	learn: 1.1166213	total: 398ms	remaining: 171ms
# 210:	learn: 1.1140073	total: 402ms	remaining: 169ms
# 211:	learn: 1.1128506	total: 403ms	remaining: 167ms
# 212:	learn: 1.1126750	total: 405ms	remaining: 165ms
# 213:	learn: 1.1121601	total: 406ms	remaining: 163ms
# 214:	learn: 1.1072486	total: 408ms	remaining: 161ms
# 215:	learn: 1.1062399	total: 410ms	remaining: 159ms
# 216:	learn: 1.1035778	total: 411ms	remaining: 157ms
# 217:	learn: 1.1024797	total: 413ms	remaining: 155ms
# 218:	learn: 1.1012393	total: 415ms	remaining: 153ms
# 219:	learn: 1.0975025	total: 416ms	remaining: 151ms
# 220:	learn: 1.0932208	total: 418ms	remaining: 149ms
# 221:	learn: 1.0886386	total: 419ms	remaining: 147ms
# 222:	learn: 1.0863830	total: 421ms	remaining: 145ms
# 223:	learn: 1.0854296	total: 422ms	remaining: 143ms
# 224:	learn: 1.0809588	total: 424ms	remaining: 141ms
# 225:	learn: 1.0786110	total: 426ms	remaining: 139ms
# 226:	learn: 1.0772691	total: 427ms	remaining: 137ms
# 227:	learn: 1.0732781	total: 429ms	remaining: 135ms
# 228:	learn: 1.0702632	total: 431ms	remaining: 133ms
# 229:	learn: 1.0691062	total: 432ms	remaining: 132ms
# 230:	learn: 1.0662515	total: 434ms	remaining: 130ms
# 231:	learn: 1.0649791	total: 435ms	remaining: 128ms
# 232:	learn: 1.0633650	total: 437ms	remaining: 126ms
# 233:	learn: 1.0621828	total: 439ms	remaining: 124ms
# 234:	learn: 1.0577917	total: 441ms	remaining: 122ms
# 235:	learn: 1.0568467	total: 442ms	remaining: 120ms
# 236:	learn: 1.0557739	total: 444ms	remaining: 118ms
# 237:	learn: 1.0541290	total: 446ms	remaining: 116ms
# 238:	learn: 1.0503025	total: 447ms	remaining: 114ms
# 239:	learn: 1.0466095	total: 449ms	remaining: 112ms
# 240:	learn: 1.0425015	total: 451ms	remaining: 110ms
# 241:	learn: 1.0389226	total: 452ms	remaining: 108ms
# 242:	learn: 1.0377517	total: 454ms	remaining: 106ms
# 243:	learn: 1.0364667	total: 456ms	remaining: 105ms
# 244:	learn: 1.0338418	total: 457ms	remaining: 103ms
# 245:	learn: 1.0309862	total: 459ms	remaining: 101ms
# 246:	learn: 1.0281907	total: 460ms	remaining: 98.7ms
# 247:	learn: 1.0241382	total: 462ms	remaining: 96.8ms
# 248:	learn: 1.0206674	total: 463ms	remaining: 94.9ms
# 249:	learn: 1.0204252	total: 465ms	remaining: 93ms
# 250:	learn: 1.0198367	total: 466ms	remaining: 91ms
# 251:	learn: 1.0180040	total: 468ms	remaining: 89.1ms
# 252:	learn: 1.0172476	total: 470ms	remaining: 87.2ms
# 253:	learn: 1.0131301	total: 471ms	remaining: 85.3ms
# 254:	learn: 1.0129207	total: 473ms	remaining: 83.4ms
# 255:	learn: 1.0106878	total: 474ms	remaining: 81.5ms
# 256:	learn: 1.0096311	total: 476ms	remaining: 79.6ms
# 257:	learn: 1.0053793	total: 477ms	remaining: 77.7ms
# 258:	learn: 1.0048379	total: 479ms	remaining: 75.8ms
# 259:	learn: 1.0013640	total: 480ms	remaining: 73.9ms
# 260:	learn: 1.0007401	total: 482ms	remaining: 72ms
# 261:	learn: 0.9976656	total: 484ms	remaining: 70.1ms
# 262:	learn: 0.9974348	total: 485ms	remaining: 68.3ms
# 263:	learn: 0.9944641	total: 487ms	remaining: 66.4ms
# 264:	learn: 0.9919346	total: 488ms	remaining: 64.5ms
# 265:	learn: 0.9893400	total: 490ms	remaining: 62.6ms
# 266:	learn: 0.9866037	total: 492ms	remaining: 60.8ms
# 267:	learn: 0.9840258	total: 493ms	remaining: 58.9ms
# 268:	learn: 0.9812619	total: 495ms	remaining: 57ms
# 269:	learn: 0.9785226	total: 496ms	remaining: 55.1ms
# 270:	learn: 0.9742806	total: 498ms	remaining: 53.3ms
# 271:	learn: 0.9739178	total: 499ms	remaining: 51.4ms
# 272:	learn: 0.9707041	total: 500ms	remaining: 49.5ms
# 273:	learn: 0.9684514	total: 502ms	remaining: 47.6ms
# 274:	learn: 0.9640214	total: 503ms	remaining: 45.7ms
# 275:	learn: 0.9606330	total: 505ms	remaining: 43.9ms
# 276:	learn: 0.9581523	total: 506ms	remaining: 42ms
# 277:	learn: 0.9578247	total: 507ms	remaining: 40.1ms
# 278:	learn: 0.9560118	total: 508ms	remaining: 38.3ms
# 279:	learn: 0.9540408	total: 510ms	remaining: 36.4ms
# 280:	learn: 0.9515369	total: 512ms	remaining: 34.6ms
# 281:	learn: 0.9484774	total: 514ms	remaining: 32.8ms
# 282:	learn: 0.9473400	total: 517ms	remaining: 31.1ms
# 283:	learn: 0.9462860	total: 519ms	remaining: 29.2ms
# 284:	learn: 0.9435331	total: 523ms	remaining: 27.5ms
# 285:	learn: 0.9432631	total: 525ms	remaining: 25.7ms
# 286:	learn: 0.9393249	total: 527ms	remaining: 23.9ms
# 287:	learn: 0.9356634	total: 528ms	remaining: 22ms
# 288:	learn: 0.9335548	total: 530ms	remaining: 20.2ms
# 289:	learn: 0.9322649	total: 531ms	remaining: 18.3ms
# 290:	learn: 0.9289419	total: 533ms	remaining: 16.5ms
# 291:	learn: 0.9271718	total: 534ms	remaining: 14.6ms
# 292:	learn: 0.9264750	total: 536ms	remaining: 12.8ms
# 293:	learn: 0.9232360	total: 537ms	remaining: 11ms
# 294:	learn: 0.9209530	total: 539ms	remaining: 9.13ms
# 295:	learn: 0.9192065	total: 540ms	remaining: 7.3ms
# 296:	learn: 0.9187962	total: 542ms	remaining: 5.47ms
# 297:	learn: 0.9172230	total: 543ms	remaining: 3.65ms
# 298:	learn: 0.9169749	total: 545ms	remaining: 1.82ms
# 299:	learn: 0.9151395	total: 546ms	remaining: 0us

# %%
coef_table = pd.DataFrame({'features' : list(X_train.columns), 'weights' : cb.feature_importances_})

coef_table.sort_values(by='weights')
# Out:
#            features    weights
# 7   weekday_average   1.806445
# 10     year_average   2.969726
# 5             lag_8   4.467766
# 4             lag_7   5.175929
# 3             lag_6   5.915737
# 2             lag_5   5.939915
# 9     month_average   9.896269
# 6             lag_9   9.983806
# 0             lag_3  10.271374
# 8      week_average  21.034983
# 1             lag_4  22.538051

# %% [markdown]
# ## Библиотеки для работы с временными рядами
#
# Для работы с временными рядами существует несколько хороших библиотек. Мы немного посмотрим на библиотеку ETNA, но есть и другие.
#
# Среди них: библиотека от Facebook [Prophet](https://github.com/facebook/prophet), [tsfresh](https://github.com/blue-yonder/tsfresh), [darts](https://github.com/unit8co/darts) и другие (можно посмотреть на github).

# %% [markdown]
# Источники:
#
# 1. Пост на Хабре от ODS https://habr.com/ru/company/ods/blog/327242/
# 2. Онлайн-учебник курса по продвинутому статистическому прогнозированию университета Duke  https://people.duke.edu/~rnau/411home.htm

# %% [markdown]
# # ETNA (от Тинькофф)
#
# Первая общедоступная версия библиотеки появилась в сентябре 2021 г.

# %%
# !pip install etna -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 332.9/332.9 kB 6.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 354.0/354.0 kB 35.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.8/135.8 kB 15.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.1/11.1 MB 100.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 15.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.2/57.2 kB 7.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 86.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 9.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 95.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 72.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 292.8/292.8 kB 36.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 5.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.8/79.8 kB 10.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.5/34.5 MB 18.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 16.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 80.8 MB/s eta 0:00:00
#   Building wheel for antlr4-python3-runtime (setup.py) ... done

# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/aiedu-courses/stepik_applied_tasks/main/datasets/DailyDelhiClimateTrain.csv')

df = df[['date','meantemp']]

# %% [markdown]
# Приведем данные к формату, с которым работает ETNA:
#
# * колонка `timestamp` - время в формате datetime
# * колонка `target` - целевая переменная (прогнозируемый ряд)
# * колонка `segment` - `main` в случае, если целевая переменная - это один ряд

# %%
df["timestamp"] = pd.to_datetime(df["date"])
df["target"] = df["meantemp"]
df.drop(columns=["date", "meantemp"], inplace=True)
df["segment"] = "main"

df.head()
# Out:
#    timestamp     target segment
# 0 2013-01-01  10.000000    main
# 1 2013-01-02   7.400000    main
# 2 2013-01-03   7.166667    main
# 3 2013-01-04   8.666667    main
# 4 2013-01-05   6.000000    main

# %% [markdown]
# В ETNA есть специальный класс для работы с временными рядами - TSDataset, приведем наши данные к этому формату.

# %%
from etna.datasets.tsdataset import TSDataset

df = TSDataset.to_dataset(df)
df.head()
# Out:
# segment          main
# feature        target
# timestamp
# 2013-01-01  10.000000
# 2013-01-02   7.400000
# 2013-01-03   7.166667
# 2013-01-04   8.666667
# 2013-01-05   6.000000

# %% [markdown]
# Укажем временной шаг (дни).

# %%
ts = TSDataset(df, freq="D")

ts.head()
# Out:
# segment          main
# feature        target
# timestamp
# 2013-01-01  10.000000
# 2013-01-02   7.400000
# 2013-01-03   7.166667
# 2013-01-04   8.666667
# 2013-01-05   6.000000

# %%
ts.info()
# Out:
# <class 'etna.datasets.TSDataset'>
# num_segments: 1
# num_exogs: 0
# num_regressors: 0
# num_known_future: 0
# freq: D
#          start_timestamp end_timestamp  length  num_missing
# segments
# main          2013-01-01    2016-12-31    1461            0

# %%
ts.describe()
# Out:
#          start_timestamp end_timestamp  length  num_missing  num_segments  \
# segments
# main          2013-01-01    2016-12-31    1461            0             1
#
#           num_exogs  num_regressors  num_known_future freq
# segments
# main              0               0                 0    D

# %%
ts.plot()

# %% [markdown]
# Разбиваем данные на тренировочную и тестовую части

# %%
train_ts, test_ts = ts.train_test_split(
    train_start="2013-01-01",
    train_end="2015-12-31",
    test_start="2016-01-01",
    test_end="2016-12-31",
)

# %% [markdown]
# В библиотеке ETNA реализовано множество самых разных моделей - от классической SARIMAX до нейронных сетей.
#
# Обучим самую простую модель из ETNA - NaiveModel.
#
# Наивная модель предсказывает текущее значение, равное значению ряда несколько периодов назад (lag):
#
# $$y_t = y_{t-lag}$$

# %%
HORIZON = 366 # горизонт прогнозирования

from etna.models import NaiveModel, CatBoostMultiSegmentModel, LinearPerSegmentModel, SARIMAXModel

# Fit the model
model1 = NaiveModel(lag=5)

model1.fit(train_ts)

# Make the forecast
future_ts = train_ts.make_future(future_steps=HORIZON, tail_steps=model1.context_size)

forecast_ts = model1.forecast(future_ts, prediction_size=HORIZON)

# %%
from etna.metrics import SMAPE

smape = SMAPE()
smape(y_true=test_ts, y_pred=forecast_ts)
# Out:
# {'main': 50.067909843390055}

# %%
from etna.analysis import plot_forecast

plot_forecast(forecast_ts, test_ts, train_ts, n_train_samples=10)

# %% [markdown]
# ### Prophet (от Facebook)
#
# Библиотека Prophet использует аддитивную модель для прогнозирования временных рядов. Аддитивная модель предполагает, что значение временного ряда можно разложить на несколько компонент, таких как тренд, сезонность, праздничные эффекты и остатки.
#
# Модель Prophet выражается следующим уравнением:
#
# $$y_t = g_t + s_t + h_t + e_t,$$
#
# где:
#
# * $g_t$ представляет тренд, моделирующий нелинейное изменение значения временного ряда во времени
#
# * $s_t$ представляет сезонность, учитывающую повторяющиеся паттерны или циклы во временном ряду
#
# * $h_t$ представляет праздничные эффекты, учитывающие влияние праздников и событий на временной ряд
#
# * $e_t$ представляет остатки, которые предполагаются нормально распределенными шумами вокруг модели
#
# Тренд моделируется с использованием гибкой линейной модели, которая может аппроксимировать нелинейные изменения во временном ряду. Сезонность моделируется с помощью фурье-рядов, позволяющих учесть сезонные колебания с различными периодами. Праздничные эффекты моделируются путем добавления индикаторов праздников в модель.
#
# Prophet также автоматически настраивает гиперпараметры модели, такие как гибкость тренда и сезонности, а также влияние праздников. Он также предоставляет возможность пользователю настраивать некоторые параметры, такие как сезонность, шум и другие.

# %%
from etna.models import ProphetModel

model2 = ProphetModel()

model2.fit(train_ts)

# Make the forecast
future_ts = train_ts.make_future(HORIZON)
forecast_ts = model2.forecast(future_ts)
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5u7sw88s/5pv24khu.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5u7sw88s/bj8c8v23.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=58005', 'data', 'file=/tmp/tmp5u7sw88s/5pv24khu.json', 'init=/tmp/tmp5u7sw88s/bj8c8v23.json', 'output', 'file=/tmp/tmp5u7sw88s/prophet_model1kljocnk/prophet_model-20230804162552.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:25:52 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:25:52 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
smape(y_true=test_ts, y_pred=forecast_ts)
# Out:
# {'main': 10.532028749602292}

# %%
plot_forecast(forecast_ts, test_ts, train_ts, n_train_samples=10)

# %% [markdown]
# # Pipeline
#
# Для обучения и валидации модели будем использовать сущность `Pipeline`. В целом, использование `Pipeline` позволит ускорить и упростить обучение и тестирование модели. Например, разбиение на тренировочные и тестовые выборки при запуске кросс валидации в таком случае будет производиться автоматически.
#
# `Pipeline` имеет несколько параметров:
#
# * `model` - модель, которая будет обучаться и тестироваться;
# * `horizon` - горизонт прогнозирования;
# * `transforms` - список преобразований, которые нужно применить к данным.
#
# Ещё одним достоинством использования пайплайна является автоматическое прямое и обратное преобразование данных, следовательно, о согласованности данных можно не беспокоиться. Кросс валидацию на исторических данных можно запустить с помощью метода `backtest`.

# %%
from etna.pipeline import Pipeline
from etna.metrics import MAE, SMAPE
from etna.transforms import STLTransform, LagTransform, MeanSegmentEncoderTransform

pipe = Pipeline(
    transforms=[
        STLTransform(in_column="target", period=7, model="arima"),
        LagTransform(in_column="target", lags=list(range(3, 10, 1))),
    ],
    model=LinearPerSegmentModel(),
    horizon=3
)

# %% [markdown]
# ## Backtest
#
# Backtest - это кросс-валидация на временных рядах.

# %%
metrics, forecast, _ = pipe.backtest(
    ts=ts, metrics=[MAE(), SMAPE()], n_folds=5)

metrics
# Out:
# [Parallel(n_jobs=1)]: Done   1 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=1)]: Done   2 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=1)]: Done   3 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=1)]: Done   4 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=1)]: Done   5 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=1)]: Done   5 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=1)]: Done   1 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done   2 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=1)]: Done   3 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=1)]: Done   4 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=1)]: Done   5 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=1)]: Done   5 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=1)]: Done   1 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done   2 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done   3 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done   4 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done   5 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done   5 tasks      | elapsed:    0.1s
#   segment       MAE      SMAPE  fold_number
# 0    main  0.956865   5.492141            0
# 0    main  1.679161   9.454322            1
# 0    main  1.986150  12.403313            2
# 0    main  0.500228   2.888707            3
# 0    main  0.352171   2.309867            4

# %%
mae_value = metrics.mean().to_dict()["MAE"]

mae_value
# Out:
# 1.094914868018162

# %%
from etna.analysis import plot_backtest

plot_backtest(forecast_df=forecast, ts=ts, history_len=5)

# %%
pipe2 = Pipeline(
    transforms=[
        STLTransform(in_column="target", period=7, model="arima"),
        LagTransform(in_column="target", lags=list(range(3, 10, 1))),
    ],
    model=CatBoostMultiSegmentModel(n_estimators=1000, learning_rate=0.01),
    horizon=3
)

# %%
metrics, forecast, _ = pipe2.backtest(
    ts=ts, metrics=[MAE(), SMAPE()], n_folds=5)

metrics
# Out:
# [Parallel(n_jobs=1)]: Done   1 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=1)]: Done   2 tasks      | elapsed:    4.8s
# [Parallel(n_jobs=1)]: Done   3 tasks      | elapsed:    6.4s
# [Parallel(n_jobs=1)]: Done   4 tasks      | elapsed:    8.0s
# [Parallel(n_jobs=1)]: Done   5 tasks      | elapsed:    9.6s
# [Parallel(n_jobs=1)]: Done   5 tasks      | elapsed:    9.6s
# [Parallel(n_jobs=1)]: Done   1 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done   2 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done   3 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=1)]: Done   4 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=1)]: Done   5 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=1)]: Done   5 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=1)]: Done   1 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done   2 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done   3 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done   4 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done   5 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done   5 tasks      | elapsed:    0.1s
#   segment       MAE      SMAPE  fold_number
# 0    main  0.606679   3.509500            0
# 0    main  1.688889   9.534459            1
# 0    main  2.000959  12.491365            2
# 0    main  0.399407   2.309858            3
# 0    main  0.238378   1.558969            4

# %%
mae_value = metrics.mean().to_dict()["MAE"]

mae_value
# Out:
# 0.9868626308337773

# %%
plot_backtest(forecast_df=forecast, ts=ts, history_len=5)

# %% [markdown]
# Примеры ноутбуков с использованием ETNA:
#
# * [tutorial из документации](https://github.com/tinkoff-ai/etna/blob/master/examples/get_started.ipynb)
#
# * [семинар с курса "Прикладные задачи машинного обучения" в ВШЭ](https://github.com/hse-ds/iad-applied-ds/blob/master/2023/seminars/sem07_ts2/sem07_ts2.ipynb)

# %% [markdown]
# ## Учет экзогенных факторов

# %%
df = pd.read_csv('https://raw.githubusercontent.com/aiedu-courses/stepik_applied_tasks/main/datasets/DailyDelhiClimateTrain.csv')

df['date'] = pd.to_datetime(df['date'], format = '%Y-%m-%d')

df.head()
# Out:
#         date   meantemp   humidity  wind_speed  meanpressure
# 0 2013-01-01  10.000000  84.500000    0.000000   1015.666667
# 1 2013-01-02   7.400000  92.000000    2.980000   1017.800000
# 2 2013-01-03   7.166667  87.000000    4.633333   1018.666667
# 3 2013-01-04   8.666667  71.333333    1.233333   1017.166667
# 4 2013-01-05   6.000000  86.833333    3.700000   1016.500000

# %%
df = df[['date','meantemp','meanpressure']].set_index('date')

# %%
def preprocess_data_exog(data, lag_start=5, lag_end=20, test_size=0.15):

    exog = "meanpressure"

    data = pd.DataFrame(data.copy())

    # считаем индекс в датафрейме, после которого начинается тестовый отрезок
    test_index = int(len(data) * (1 - test_size))

    # добавляем лаги исходного ряда в качестве признаков
    for i in range(lag_start, lag_end):
        data[f"lag_{i}"] = data.meantemp.shift(i)
        data[f"lag_exog_{i}"] = data[exog].shift(i)

    data["weekday"] = data.index.weekday
    data["week"] = data.index.week
    data["month"] = data.index.month
    data["year"] = data.index.year

    # считаем средние только по тренировочной части, чтобы избежать лика (data leak)
    data["weekday_average"] = list(map(code_mean(data[:test_index], "weekday", "meantemp").get, data.weekday))
    data["week_average"] = list(map(code_mean(data[:test_index], "week", "meantemp").get, data.week))
    data["month_average"] = list(map(code_mean(data[:test_index], "month", "meantemp").get, data.month))
    data["year_average"] = list(map(code_mean(data[:test_index], "year", "meantemp").get, data.year))

    data["weekday_average_exog"] = list(map(code_mean(data[:test_index], "weekday", exog).get, data.weekday))
    data["week_average_exog"] = list(map(code_mean(data[:test_index], "week", exog).get, data.week))
    data["month_average_exog"] = list(map(code_mean(data[:test_index], "month", exog).get, data.month))
    data["year_average_exog"] = list(map(code_mean(data[:test_index], "year", exog).get, data.year))

    # выкидываем закодированные средними признаки
    data.drop(["weekday", "week", "month", "year", exog], axis=1, inplace=True)

    data = data.dropna()
    data = data.reset_index(drop=True)

    # разбиваем весь датасет на тренировочную и тестовую выборку
    X_train = data.loc[:test_index].drop(["meantemp"], axis=1)
    y_train = data.loc[:test_index]["meantemp"]
    X_test = data.loc[test_index:].drop(["meantemp"], axis=1)
    y_test = data.loc[test_index:]["meantemp"]

    return X_train, X_test, y_train, y_test

# %%
X_train_big, X_test_big, y_train, y_test = preprocess_data_exog(df, test_size=0.3, lag_start=3, lag_end=10)

X_train_big.head()
# Out:
#        lag_3   lag_exog_3      lag_4   lag_exog_4      lag_5   lag_exog_5  \
# 0   7.000000  1020.000000   7.000000  1018.000000   6.000000  1016.500000
# 1   8.857143  1018.714286   7.000000  1020.000000   7.000000  1018.000000
# 2  14.000000  1017.000000   8.857143  1018.714286   7.000000  1020.000000
# 3  11.000000  1015.666667  14.000000  1017.000000   8.857143  1018.714286
# 4  15.714286  1016.142857  11.000000  1015.666667  14.000000  1017.000000
#
#       lag_6   lag_exog_6     lag_7   lag_exog_7  ...      lag_9   lag_exog_9  \
# 0  8.666667  1017.166667  7.166667  1018.666667  ...  10.000000  1015.666667
# 1  6.000000  1016.500000  8.666667  1017.166667  ...   7.400000  1017.800000
# 2  7.000000  1018.000000  6.000000  1016.500000  ...   7.166667  1018.666667
# 3  7.000000  1020.000000  7.000000  1018.000000  ...   8.666667  1017.166667
# 4  8.857143  1018.714286  7.000000  1020.000000  ...   6.000000  1016.500000
#
#    weekday_average  week_average  month_average  year_average  \
# 0        25.440460     11.925454      12.738377     24.791494
# 1        25.372054     11.925454      12.738377     24.791494
# 2        25.331414     11.925454      12.738377     24.791494
# 3        25.202210     11.925454      12.738377     24.791494
# 4        25.499234     13.067177      12.738377     24.791494
#
#    weekday_average_exog  week_average_exog  month_average_exog  \
# 0           1007.715550        1017.573980         1018.552483
# 1           1007.542990        1017.573980         1018.552483
# 2           1007.585645        1017.573980         1018.552483
# 3           1007.803264        1017.573980         1018.552483
# 4           1007.899013        1018.442744         1018.552483
#
#    year_average_exog
# 0        1007.642172
# 1        1007.642172
# 2        1007.642172
# 3        1007.642172
# 4        1007.642172
#
# [5 rows x 22 columns]

# %% [markdown]
# Заново обучим линейную регрессию на исходных данных (чтобы затем сравнить)

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
preds = lr.predict(X_test)

plt.figure(figsize=(10, 5))
plt.plot(preds, "r", label="prediction")
plt.plot(y_test.values, label="actual")
plt.grid(True)
plt.legend(loc="best")
plt.title(f"Linear regression\n Mean absolute error {mean_absolute_error(preds, y_test)} degrees");

# %% [markdown]
# Теперь обучим модель на данных с учетом экзогенных факторов

# %%
lr = LinearRegression()
lr.fit(X_train_big, y_train)
preds = lr.predict(X_test_big)

plt.figure(figsize=(10, 5))
plt.plot(preds, "r", label="prediction")
plt.plot(y_test.values, label="actual")
plt.grid(True)
plt.legend(loc="best")
plt.title(f"Linear regression\n Mean absolute error {mean_absolute_error(preds, y_test)} degrees");

# %%
coef_table = pd.DataFrame({'features' : list(X_train_big.columns), 'weights' : lr.coef_})

coef_table.sort_values(by='weights')
